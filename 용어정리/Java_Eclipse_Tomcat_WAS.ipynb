# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/%EC%9A%A9%EC%96%B4%EC%A0%95%EB%A6%AC/Java_Eclipse_Tomcat_WAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JDK Download
# jdk-8u291-windows-x64
# 관리자권한으로 실행
#
# 내pc - 우클릭 - 속성 - 고급시스템설정 - 환경변수 - 시스템변수 - 새로만들기 - 자바가 설치된 경로의 변수(JAVA_HOME)를 등록
#
# ![ddd.png](data:image/png;base64,...)
#
# 시스템변수 Path에 %JAVA_HOME%\BIN\ 추가
#
# 이렇게 설정해주면 cmd창에서 javac -version이 잘나옴

# %% [markdown]
# https://projects.eclipse.org/
# javaEE 검색
# Jakarta Expression Language 눈도장
#
# https://www.eclipse.org/
#
#       1. 우측상단 Download 클릭 - Download - 2번째 것(for Enterprise Java and Web Developers) 설치
#       2. 우측상단 Download 클릭 - Download Packages 클릭 - Eclipse IDE for Enterprise Java and Web Developers 다운로드
#
#
# 컴파일러 1.8로 변경
#
# ![ddd.png](data:image/png;base64,...)

# %% [markdown]
# ## Tomcat: WAS(Web Application Server), Node.js와 비슷
#
# https://tomcat.apache.org/download-90.cgi
# tomcat 9
# 64-bit Windows zip (pgp, sha512) 설치
#
# - 자바기반으로 jsp/servlet(동적페이지)이 있음
# - 클라이언트(외부)가 http://ip:port/Test/a.html 로 WAS(Test/a.html)에 접속이 가능
# - apache-tomcat-9.0.45 - webapps - Test폴더 생성 - a.html 만들기
# - apache-tomcat-9.0.45 - bin - startup.bat(열어둔 상태에서) - localhost:8080 - http://localhost:8080/Test/a.html 또는 http://172.30.1.52:8080/Test/a.html
# - apache-tomcat-9.0.45 - logs에 클라이언트의 로그데이터가 기록됨
# - shutdown.bat
#
# ![r.png](data:image/png;base64,...)

# %% [markdown]
# ## 1이 2를 포함하고 2가 3을 포함하고... 포함관계
# 1. application: 동적 또는 정적 페이지가 있는 폴더명 ex)Test
# 2. context로 연동: url 매핑 ex)http://ip:port/Test/a.html 또는 http://ip:port/Test/b.jsp 에서의 Test
# 3. context 안에 여러개의 session: client정보를 가지고 객체 생성, 접속한 순간 session의 객체가 생성
# 4. Request
# 5. webpage: <- servlet <- jsp, html, img

# %% [markdown]
# ## 웹페이지
# 1. 동적페이지: 클라이언트가 입력한 값을 처리, asp/aspx/php/jsp, 게시판/방명록/회원가입/장바구니 등
# 2. 정적페이지: html(Hyper Text Markup Language)

# %% [markdown]
# ## (참고)MEAN stack
# - MongoDB - document database
# - Express(.js) - Node.js web framework(client가 framework를 가져다가 기능을 확장해서 씀)
# - Angular(.js) - a client-side JavaScript framework
# - Node(.js) - the premier JavaScript web server
#
# ![dd.png](data:image/png;base64,...)

# %% [markdown]
# 이클립스
#
# ![ss.png](data:image/png;base64,...)
#
#
# ![sss.png](data:image/png;base64,...)

# %% [markdown]
# 왼쪽에 Create a Dynamic Web project
#
# ![fef.png](data:image/png;base64,...)
#
# ![22.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)
#
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %%
package com.test;

public class Test {
	public static void main(String[] args) {
		System.out.println("한줄 써보자. ");
		System.out.println("~~~~~~~~~");
	}
}

//ctrl + F11
