# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/%EC%8B%9C%EA%B3%84%EC%97%B4%EB%8D%B0%EC%9D%B4%ED%84%B0_%EA%B0%9C%EB%85%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 시계열 데이터(Time Series Data)란?
# *  개념: 데이터를 시간의 흐름에 따라 나열한 것
# *  특성: 지속적으로 업데이트되는 데이터, 동일한 시간 간격으로 관찰된 데이터
# *  활용: 미래예측, 2개 이상의 시계열 간의 상관관계를 통해 서로 어떤 영향을 주는지 분석

# %% [markdown]
# # 2. 시계열 데이터의 분류
# *  Trend: 전반적으로 증가 또는 감소하는 패턴
# *  Seasonality: 규칙적인 주기에 따라 반복되는 패턴
# *  Cyclicity: 주기가 규칙적이지 않지만 반복되는 패턴
# *  Random noise: 불규칙한 파동
#
# ![1_801_G0ClBVBBTSWr_bPyCQ.png](data:image/png;base64,...)

# %% [markdown]
# # 3. 시계열 데이터의 모형

# %% [markdown]
# ## 3-1. 단변량: 단순회귀처럼 1개의 독립변수로 미래 시점의 어떤 값(종속변수)을 예측
# *  이동평균(MA, Moving Average): 일정기간별 평균을 계산하고 이들의 추세를 파악하여 다음 기간을 예측하는 방법, 적절한 기간을 사용하는 것이 핵심
#
# ![MA.png](data:image/png;base64,...)

# %% [markdown]
# ##3-2. 다변량: 다중회귀처럼 2개 이상의 독립변수로 미래 시점의 어떤 값(종속변수)을 예측
