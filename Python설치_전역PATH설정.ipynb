# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/Python%EC%84%A4%EC%B9%98_%EC%A0%84%EC%97%ADPATH%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -  내 PC - 속성 - 고급시스템설정 - 환경변수 - 전역PATH 설정
# C:\Python\Python39
# C:\Python\Python39\Scripts
#   1. 사용자변수
#   2. 시스템변수(관리자권한)

# %% [markdown]
# -  dll(dynamic link library): 참조형 실행파일, 참조 당하는 파일이기 때문에 실행메모리를 차지하지 않음, 즉 exe가 실행할 때 dll을 참조, dll을 넣고 exe를 만들어야 메모리가 작아서 빠름
# -  exe: 그냥 실행파일

# %% [markdown]
# ![python.png](data:image/png;base64,...)

# %% [markdown]
# ![script.png](data:image/png;base64,...)
