# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/1_11_%EC%9B%B9_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EC%A4%91%EA%B3%A0%EC%84%9C%EC%A0%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
from bs4 import BeautifulSoup

# %%
w = open("중고서적_리스트_가격.txt", "w")
page_num = 1
while True:
  url = "https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Used&KeyWord=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&KeyRecentPublish=0&OutStock=0&ViewType=Detail&SortOrder=11&CustReviewCount=0&CustReviewRank=0&KeyFullWord=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&KeyLastWord=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&CategorySearch=&chkKeyTitle=&chkKeyAuthor=&chkKeyPublisher=&ViewRowCount=25&page={}".format(page_num)
  code = req.urlopen(url)
  soup = BeautifulSoup(code, "html.parser")

  title = soup.select("a.bo3 > b")
  price = soup.select("a.bo_used > b")
  if len(title) == 0:
    break
  for i in range(len(title)):
    print(title[i].string, price[i].string)
    w.write(title[i].string + ", " + price[i].string + "\n")
  page_num += 1
w.close()
# Out:
# 핸즈온 머신러닝 49,500원
# 파이썬 머신러닝 완벽 가이드  44,000원
# 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 40,900원
# 파이썬 라이브러리를 활용한 머신러닝 34,200원
# 파이썬 머신러닝 판다스 데이터 분석 29,500원
# OpenCV 4로 배우는 컴퓨터 비전과 머신 러닝 29,700원
# 패턴 인식과 머신 러닝  26,400원
# 알고리즘으로 배우는 인공지능, 머신러닝, 딥러닝 입문 23,760원
# 단단한 머신러닝 28,800원
# Kaggle 우승작으로 배우는 머신러닝 탐구생활  25,600원
# 파이썬을 활용한 머신러닝 쿡북 17,600원
# 처음 배우는 머신러닝 15,900원
# 파이썬을 이용한 머신러닝, 딥러닝 실전 개발 입문 17,000원
# 머신 러닝을 위한 수학 with 파이썬, R 22,500원
# 초소형 머신러닝 TinyML  17,000원
# 알고리즘 중심의 머신러닝 가이드 18,000원
# 핸즈온 머신러닝.딥러닝 알고리즘 트레이딩 37,800원
# 머신러닝 도감  29,400원
# 나의 첫 머신러닝 / 딥러닝 28,500원
# 기초 수학으로 이해하는 머신러닝 알고리즘 41,400원
# 실전 금융 머신러닝 완벽 분석 21,700원
# R을 활용한 머신러닝 3/e 30,000원
# 머신러닝과 블록체인을 떠받치는 GPU의 모든 기술 24,300원
# 파이썬을 이용한 머신러닝, 딥러닝 실전 앱 개발 12,700원
# 머신러닝 실무 프로젝트 10,000원
# Machine Learning 머신 러닝 54,000원
# 실무가 훤히 보이는 머신러닝 & 딥러닝 42,000원
# 헬스케어 인공지능과 머신러닝 23,400원
# 만화로 쉽게 배우는 머신러닝  20,800원
# 파이썬으로 배우는 머신러닝의 교과서 12,300원
# 머신러닝 인 액션 18,200원
# 머신 러닝을 활용한 컴퓨터 보안 31,500원
# 머신러닝을 이용한 알고리즘 트레이딩 시스템 개발 27,900원
# ...
