# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('민정_Data Scientist')
# Out:
# 민정_Data Scientist

# %%
# !git clone https://github.com/mjkimcs/portfolio2.git
# Out:
# fatal: destination path 'portfolio2' already exists and is not an empty directory.
