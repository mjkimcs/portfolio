# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/c_API_%ED%8C%8C%ED%8C%8C%EA%B3%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://developers.naver.com/docs/common/openapiguide/
# 비로그인방식 오픈API

# %%
api_id = "1dtjfDcnaFtDzlaE5msG"
api_pw = "1vDWU9Lwo0"

# %% [markdown]
# 예제 코드 링크: https://developers.naver.com/docs/nmt/examples/

# %%
import os
import sys
import urllib.request
import json

sentence = input("번역할 문장 입력>>")

api_id = "1dtjfDcnaFtDzlaE5msG"
api_pw = "1vDWU9Lwo0"

client_id = api_id
client_secret = api_pw
encText = urllib.parse.quote(sentence)
data = "source=ko&target=en&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    result_dict = json.loads(result) #json -> 딕셔너리
    print(result_dict["message"]["result"]["translatedText"])
else:
    print("Error Code:" + rescode)
# Out:
# 번역할 문장 입력>>반가워
# Good to see you.

# %%
import urllib.request as req
from bs4 import BeautifulSoup
import re

import os
import sys
import urllib.request
import json

keyword = input("영어로 키워드 입력 >> ")
url = "http://www.koreaherald.com/search/index.php?q={}&sort=1&mode=list&np=1&mp=1".format(keyword)
code = req.urlopen(url)
soup = BeautifulSoup(code, "html.parser")
articles = soup.select("ul.main_sec_li > li > a")
for i in articles[0:3]:
  title = i.select_one("div.main_l_t1")
  print("제목: ", title.text)
  link = "http://www.koreaherald.com" + i.attrs["href"]
  code_2 = req.urlopen(link)
  soup_2 = BeautifulSoup(code_2, "html.parser")
  contents = soup_2.select_one("div#articleText")
  result = re.sub(r'(\\[x]..)|(\\r)|(\\n)|(\\t)|(\(Yonhap\))', "", contents.text.strip()) #strip(): 앞뒤 공백제거
  # print(result)
  # print()

  if len(result) > 5000: #무료API라서 5000자까지만 번역이 가능
      result = result[0:5000]

  api_id = "zdSrRqsx3ZIYHZXaIVny"
  api_pw = "2aao0ARARA"

  client_id = api_id
  client_secret = api_pw
  encText = urllib.parse.quote(result)
  data = "source=en&target=ko&text=" + encText #출발언어는 영어, 도착언어는 한국어
  url = "https://openapi.naver.com/v1/papago/n2mt"
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request, data=data.encode("utf-8"))
  rescode = response.getcode()
  if (rescode==200):
      response_body = response.read()
      result = response_body.decode('utf-8')
      result_dict = json.loads(result) #json -> 딕셔너리
      print(result_dict["message"]["result"]["translatedText"])
      print() #개행
  else:
      print("Error Code:" + rescode)
# Out:
# 영어로 키워드 입력 >> kaist+summit
# 제목:  KAIST to hold online forum with MIT, Tokyo Tech, Northwestern University
# KAIST 정상회의 포스터(KAIST 공식 홈페이지)국내 유수의 과학기술대학인 한국과학기술원이 코로나19 시대에 산업 분야에서 경쟁력을 확보할 수 있는 방안을 모색하며 다른 유명 대학 3곳과 함께 온라인 포럼을 시작한다. 글로벌 위기 속에서 대학의 역할과 책임이라는 온라인 포럼은 4차 산업혁명 시대 대학들에 영향을 미치는 다양한 이슈들을 담아 26일 생중계된다.KAIST 정상회의는 2시간 동안 KAIST, MIT, 도쿄테크, 노스웨스턴대 총장들을 개최한다. 기조연설자는 신성철 KAIST 총장, 라파엘 레이프 MIT 총장, 가즈야 마스 도쿄테크 총장, 모튼 샤피로 노스웨스턴대 총장 등이다. 기조연설 세션에 이어 '디지털 격차', 'AI의 새로운 도전', '사회적 기업가정신과 대학-산업 협업' 등 3개 주제에 대한 패널 토론에 연사들이 참여한다. 패널 토론에는 4IR 교란이 가져오는 정보격차를 해소하는 데 대학의 역할뿐 아니라 AI와 로봇공학이 안고 있는 윤리적 과제에 대한 심도 있는 대화가 오갈 예정이다. 강력한 산학협력 구축은 4개 대학 모두가 지향하는 핵심 목표 중 하나다. 이후 KAIST 교수진, 직원, 학생, 국내 고등학생 등으로 구성된 온라인 청중이 질의응답 시간을 가질 예정이다.신성철 KAIST 총장은 "한 가지 확실한 것은 대학이 예전처럼 존재하고 운영될 수 없다는 것"이라고 말했다. "4IR이 우리의 일상생활에 침투할 것이기 때문에 대학들이 주도적으로 과감하고 혁신적인 조치를 추구하여 사회와 지속적으로 교류해야 한다"고 신 총장은 말했다.신 총장은 또 이번 정상회담에서 교육, 연구, 기술사업화, 세계화, 미래전략 등 5개 분야에 대한 KAIST의 전략적 혁신방안을 내놓을 계획이다. KAIST 창립 50주년 기념 온라인 정상회의는 현지시간 26일 오전 10시(화) KAIST 공식 유튜브 채널(https://www.youtube.com/c/KAISTofficial),을 통해 방송된다.김해연님(hykim@heraldcorp.com)
#
# 제목:  Church elder’s view of current events
# 김명식(Qumran Books)의 '올인더보트'김명식 코리아헤럴드·어르신 칼럼니스트는 2017년 3월부터 2020년 7월까지 한국어르신문에 쓴 140여 개의 칼럼을 엮은 '올인더보트(All in the Korea Herald and the Elders Press, and Korea Press이것은 그의 칼럼을 두 번째로 편집한 것이다. 3년치 칼럼이 담긴 '종로광장'은 2013년 출간됐다.40여 년 동안 언론계에서 김 씨는 로이터 통신 특파원, 코리아 타임즈 편집국장, 아리랑 TV 대표 등을 지냈다. 그는 또한 한국문화정보원장을 지냈고 KAIST와 한림대학교에서 교편을 잡았다. 그는 서울에 8만 명이 넘는 재적 회원을 가진 거대 교회인 소망교회의 은퇴한 장로이다.김 교수는 칼럼에서 언론인과 보수 기독교인의 시각에서 다양한 주제를 논의한다.교회 장로들이 교회 장로들을 위한 언론인 한국장로신문사에 글을 올립니다. 김씨는 "언론에 오래 몸담은 사람뿐 아니라 교회 원로로서 칼럼을 쓰고, 정책이나 최근 사건 등 온갖 주제에 대한 생각을 공유해 달라"고 당부했다.그 책은 지난 3년간의 주요 사건들을 관통하는 여행이다. 김 위원장은 2018 평창 올림픽, 공동경비구역에서의 남북 정상회담, COVID-19 전염병에 대한 자신의 견해를 다른 화두들 중에서도 공유하고 있다. 교회의 보수적 입장을 국민에게 보여주고 교회 장로들에게 공감하는 게 김 위원장의 책 목표 두 가지다.그의 칼럼 중 하나에서 나온 이 책의 제목은 분열된 사회를 통일하려는 그의 열망을 보여준다.이 책은 김 씨의 부인이 지난 1년간 보관한 3행 일지가 부록으로 마감돼 같은 사건에 대한 또 다른 시각을 보여주고 있다.임장원님(ljw@heraldcorp.com)
#
# 제목:  KAIST placed 4th in innovation in THE University Impact rankings
# 한국과학기술원이 2019 타임즈 고등교육대학 영향 순위에서 산업, 혁신, 인프라 부문에서 4위를 차지했다고 KAIST가 30일 밝혔다.  한국과학기술원(KAIST) 대전 본교에서 열린 2019 KAIST-THE 혁신&임팩트 정상회의 참석자들이 유엔 9차 달성에 있어 사회에 미치는 영향을 가늠할 수 있는 구체적인 지표 중 하나인 특허·논문·연구기금에서 거의 만점을 받았다. 산업, 혁신 및 인프라의 지속 가능한 개발 목표. 뉴질랜드 오클랜드 대학교가 THE의 전체 영향 순위에서 1위를 차지했고, 캐나다의 맥마스터 대학교가 그 뒤를 이었다. 캐나다 브리티시컬럼비아대와 영국 맨체스터대가 공동 3위에 올랐다. SDG를 기반으로 대학이 사회에 미치는 영향을 인정하는 초창기 THE University Impact Ranking은 2019 KAIST-THE Innovation & Impact Summit에서 수요일 독점 공개되어 목요일 전 세계에 발간되었다. '4차 산업혁명 시대 대학 역할 변화에 관한 정상회의'가 20일부터 30일까지 사흘간 대전 카이스트 본교에서 열려 교육산업정치 분야 25개국 300여명의 지도부가 모였다. 영향 랭킹은 기관이 17개의 SDG 중 11개의 SDG(건강과 복지, 품질 교육, 양성 평등, 양질의 노동과 경제 성장, 산업, 혁신과 인프라, 불평등 감소, 지속 가능한 소비와 생산, 기후 활동, 평화, 정의, 강력한 제도, 부분)를 성공적으로 전달한 것에 기초했습니다.목표에 대한 네거십 이 순위는 다른 순위에서 다루지 않는 기관 활동과 노력을 조사하며, 각 SDG는 연구, 홍보 및 책임의 세 가지 광범위한 영역에 걸쳐 평가된다.올해, 6개 대륙 75개국에서 500개 이상의 기관이 새로운 순위를 위한 자료를 제출했다고 THE는 말했다. 이재형 KAIST 국제실 부소장은 "글로벌 트렌드 다양화에 맞춰 대학의 역할이 다양해지면서 대학의 영향을 측정하는 지표가 달라져야 한다"며 의미 있는 노력이라고 말했다.KAIST는 지난 3월 '비전 2031'을 글로벌 가치 창출 선도 대학으로 설정한 이후 교육, 연구, 기술사업화, 세계화, 궁극적으로는 미래전략 등 5개 분야를 혁신하기 위해 노력해왔다. KAIST는 로이터가 선정한 세계에서 가장 혁신적인 대학 순위에서 2016년부터 3년 연속 아시아 최고의 혁신대학으로 선정됐다. 이 순위는 과학 선진화, 신기술 개발, 새로운 시장 및 산업에 힘을 실어주기 위해 가장 많은 노력을 기울이고 있는 교육 기관들을 인정한다. 신성철 KAIST 총장은 "유엔의 17개 SDG를 새로운 지표로 삼아 국가 발전의 성장동력이 될 수 있는 지식 생산에 전념해온 KAIST가 글로벌 가치 창출의 선도 대학이 될 것"이라고 말했다.KAIST 본교에서 사흘간 열린 정상회의에서 세계 최고 명문대 전현직 총장 및 재계 총수들은 자신들의 경험, 통찰력, 발전 전략을 공유했다. 참석자들은 교육혁신, 지식 전수 및 기업가정신, 인공지능과 문화, 혁신여행의 나선지 등 4개 주제에 대해 토론하고 4.0산업(탈태)에 대한 기관의 정책 방향을 도출하는 데 주력했다.ock@heraldcorp.com)

# %% [markdown]
# 유료버전: Naver Cloud Platform - 서비스 - AI Service - Papago NMT
