# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/%EA%B7%B8%EB%9E%98%ED%94%84_%EA%B8%B0%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("./로또.xlsx")

# %%
df
# Out:
#      숫자
# 0    10
# 1    23
# 2    29
# 3    33
# 4    37
# ..   ..
# 786  28
# 787  33
# 788  36
# 789  45
# 790  26
#
# [791 rows x 1 columns]

# %%
df.rename(columns={"숫자":"로또번호"},inplace=True)
df
# Out:
#      로또번호
# 0      10
# 1      23
# 2      29
# 3      33
# 4      37
# ..    ...
# 786    28
# 787    33
# 788    36
# 789    45
# 790    26
#
# [791 rows x 1 columns]

# %%
data = df["로또번호"].value_counts()
data
# Out:
# 1     26
# 33    25
# 26    24
# 17    24
# 6     24
# 40    23
# 37    23
# 3     21
# 7     21
# 42    20
# 27    20
# 39    20
# 36    20
# 14    19
# 29    19
# 35    19
# 44    19
# 2     19
# 43    19
# 25    19
# 10    18
# 23    18
# 30    17
# 31    17
# 16    17
# 15    17
# 4     17
# 8     17
# 21    16
# 18    16
# 32    16
# 38    16
# 20    15
# 34    14
# 24    14
# 5     14
# 11    13
# 9     13
# 13    13
# 19    13
# 41    12
# 12    12
# 22    12
# 45    12
# 28     8
# Name: 로또번호, dtype: int64

# %%
df2 = pd.DataFrame([data], index=["빈도 수"])
df2
# Out:
#       1   33  26  17  6   40  37  3   7   ...  11  9   13  19  41  12  22  45  28
# 빈도 수  26  25  24  24  24  23  23  21  21  ...  13  13  13  13  12  12  12  12   8
#
# [1 rows x 45 columns]

# %%
# 로또번호가 index인 dataframe

df2 = df2.transpose()
df2
# df2.sort_values(by="빈도 수", ascending=False)
# Out:
#     빈도 수
# 1     26
# 33    25
# 26    24
# 17    24
# 6     24
# 40    23
# 37    23
# 3     21
# 7     21
# 42    20
# 27    20
# 39    20
# 36    20
# 14    19
# 29    19
# 35    19
# 44    19
# 2     19
# 43    19
# 25    19
# 10    18
# 23    18
# 30    17
# 31    17
# 16    17
# 15    17
# 4     17
# 8     17
# 21    16
# 18    16
# 32    16
# 38    16
# 20    15
# 34    14
# 24    14
# 5     14
# 11    13
# 9     13
# 13    13
# 19    13
# 41    12
# 12    12
# 22    12
# 45    12
# 28     8

# %%
df2.index
# Out:
# Int64Index([ 1, 33, 26, 17,  6, 40, 37,  3,  7, 42, 27, 39, 36, 14, 29, 35, 44,
#              2, 43, 25, 10, 23, 30, 31, 16, 15,  4,  8, 21, 18, 32, 38, 20, 34,
#             24,  5, 11,  9, 13, 19, 41, 12, 22, 45, 28],
#            dtype='int64')

# %%
df2.columns
# Out:
# Index(['빈도 수'], dtype='object')

# %%
# index인 로또번호를 칼럼으로 변환

# df2= df2.reset_index().rename(columns={"index":"로또번호"})
# df2
# Out:
#     로또번호  빈도 수
# 0      1    26
# 1     33    25
# 2     26    24
# 3     17    24
# 4      6    24
# 5     40    23
# 6     37    23
# 7      3    21
# 8      7    21
# 9     42    20
# 10    27    20
# 11    39    20
# 12    36    20
# 13    14    19
# 14    29    19
# 15    35    19
# 16    44    19
# 17     2    19
# 18    43    19
# 19    25    19
# 20    10    18
# 21    23    18
# 22    30    17
# 23    31    17
# 24    16    17
# 25    15    17
# 26     4    17
# 27     8    17
# 28    21    16
# 29    18    16
# 30    32    16
# 31    38    16
# 32    20    15
# 33    34    14
# 34    24    14
# 35     5    14
# 36    11    13
# 37     9    13
# 38    13    13
# 39    19    13
# 40    41    12
# 41    12    12
# 42    22    12
# 43    45    12
# 44    28     8

# %%
df2["비율"] = df2["빈도 수"]/sum(df2["빈도 수"])
df2
# Out:
#     빈도 수        비율
# 1     26  0.032870
# 33    25  0.031606
# 26    24  0.030341
# 17    24  0.030341
# 6     24  0.030341
# 40    23  0.029077
# 37    23  0.029077
# 3     21  0.026549
# 7     21  0.026549
# 42    20  0.025284
# 27    20  0.025284
# 39    20  0.025284
# 36    20  0.025284
# 14    19  0.024020
# 29    19  0.024020
# 35    19  0.024020
# 44    19  0.024020
# 2     19  0.024020
# 43    19  0.024020
# 25    19  0.024020
# 10    18  0.022756
# 23    18  0.022756
# 30    17  0.021492
# 31    17  0.021492
# 16    17  0.021492
# 15    17  0.021492
# 4     17  0.021492
# 8     17  0.021492
# 21    16  0.020228
# 18    16  0.020228
# 32    16  0.020228
# 38    16  0.020228
# 20    15  0.018963
# 34    14  0.017699
# 24    14  0.017699
# 5     14  0.017699
# 11    13  0.016435
# 9     13  0.016435
# 13    13  0.016435
# 19    13  0.016435
# 41    12  0.015171
# 12    12  0.015171
# 22    12  0.015171
# 45    12  0.015171
# 28     8  0.010114

# %%
model = df2["빈도 수"].plot(kind='bar', figsize=(15,10))

# %%
model = df2["비율"].plot(kind='bar', figsize=(15,10))

# %%
model = df2.plot(kind='bar', figsize=(15,10))
model.get_legend().remove()
plt.show()

# %%
# x축이 질적자료인 경우에 쓰기 적합한 그래프

a = [1,2,3]
b = ["bag", "air", "plan"]
df_test = pd.DataFrame(data=a, index=b, columns=['Imp'])
df_test.sort_values(by='Imp', ascending=False, inplace=True)
plt.bar(df_test.index,df_test['Imp'])
# Out:
# <BarContainer object of 3 artists>

# %%
model_imp
# Out:
#       Imp
# plan    3
# air     2
# bag     1

# %%
model_imp["Imp"]
# Out:
# plan    3
# air     2
# bag     1
# Name: Imp, dtype: int64
