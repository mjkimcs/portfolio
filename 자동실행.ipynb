# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/%EC%9E%90%EB%8F%99%EC%8B%A4%ED%96%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 작업 스케줄러
# 기본작업만들기
# 파이참 - venv - Scripts - python.exe - 우클릭 - Copy Path - Absolute Path
# 프로그램/스크립트에 붙여넣기
# 인수추가 - 파이썬파일 Absolute Path 붙여넣기 - 띄어쓰기가 있다면 제일 앞뒤에 큰따옴표 해주기
# 시작위치 - 프로젝트 폴더 경로 넣기

# %% [markdown]
# [맥 버전]
# 런치패드 - 기타 - 터미널
# nano crontab -e
# 분 시 일 월 요일
# 10 * * * *  : 매시 10분마다, 1시10분, 2시10분, 3시10분
# */10 * * * * : 매 10분마다, 1시10분, 1시20분, 1시30분
# *10 * * * : 매일 오전10시마다
# (파이썬 인터프리터 경로) : venv - bin - python 끌어다놓기
# (파이썬 파일 경로) : 끌어다놓기
#
# *****(파이썬 인터프리터 경로)(파이썬 파일 경로)
#
# Ctrl+O : 저장
# 엔터
# Ctrl+X : 나오기
