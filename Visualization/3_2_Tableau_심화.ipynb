# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/Visualization/3_2_Tableau_%EC%8B%AC%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![aa.png](data:image/png;base64,...)

# %% [markdown]
# ## 필터
# - 드래그앤드롭
# - 우클릭 - 필터표시

# %% [markdown]
# ![aa.png](data:image/png;base64,...)

# %% [markdown]
# ## 대시보드 필터

# %% [markdown]
# ![aa.png](data:image/png;base64,...)

# %% [markdown]
# ![aa.png](data:image/png;base64,...)

# %% [markdown]
# ## 퀵테이블

# %% [markdown]
# ![aa.png](data:image/png;base64,...)
