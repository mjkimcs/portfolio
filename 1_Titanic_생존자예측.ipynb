# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/1_Titanic_%EC%83%9D%EC%A1%B4%EC%9E%90%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# 모델 튜닝 및 평가
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn import model_selection

# 경고 제거
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.environ['KAGGLE_USERNAME']='mjkimcs'
os.environ['KAGGLE_KEY']='3037e68094017402df6f5c07240879c2'

# %%
# !kaggle competitions download -c titanic
# !unzip '*.zip'
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# Downloading train.csv to /content
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 52.3MB/s]
# Downloading test.csv to /content
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 26.7MB/s]
# Downloading gender_submission.csv to /content
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 3.17MB/s]
# unzip:  cannot find or open *.zip, *.zip.zip or *.zip.ZIP.
#
# No zipfiles found.

# %%
# !ls
# Out:
# gender_submission.csv  sample_data  test.csv  train.csv

# %% [markdown]
# (참고)로컬PC에서 csv파일 가져오기
#
# from google.colab import files
# uploaded = files.upload()
#
# import io
# train = pd.read_csv(io.BytesIO(uploaded['train.csv']))
# test = pd.read_csv(io.BytesIO(uploaded['test.csv']))

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare        Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000          204       889
# unique          NaN         NaN         NaN  ...         NaN          147         3
# top             NaN         NaN         NaN  ...         NaN  C23 C25 C27         S
# freq            NaN         NaN         NaN  ...         NaN            4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208          NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429          NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000          NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400          NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200          NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000          NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200          NaN       NaN
#
# [11 rows x 12 columns]

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.columns[0], train.columns[3:5]
# Out:
# ('PassengerId', Index(['Name', 'Sex'], dtype='object'))

# %%
train[5:20]
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# 14           15         0       3  ...   7.8542   NaN         S
# 15           16         1       2  ...  16.0000   NaN         S
# 16           17         0       3  ...  29.1250   NaN         Q
# 17           18         1       2  ...  13.0000   NaN         S
# 18           19         0       3  ...  18.0000   NaN         S
# 19           20         1       3  ...   7.2250   NaN         C
#
# [15 rows x 12 columns]

# %%
train.shape
# Out:
# (891, 12)

# %%
# train, test 행의 갯수
ntrain = train.shape[0]
ntest = test.shape[0]

# naming
y_train = train['Survived'].values
passId = test['PassengerId']

# train, test 병합
data = pd.concat((train, test))

# 병합한 data의 크기
print("data size is: {}".format(data.shape))
# Out:
# data size is: (1309, 12)

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# train.csv에서 342명이 살아남고, 549명이 사망했다.

# %%
missingno.matrix(data, figsize = (6,4))

# %%
data.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.isna().any()
# Out:
# PassengerId    False
# Survived        True
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.isna().any().any()
# Out:
# True

# %%
data.PassengerId.isna().any()
# Out:
# False

# %%
corr = data.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(14, 8))
plt.title('Overall Correlation of Titanic Features', fontsize=18)

sns.heatmap(corr, mask=mask, annot=False, cmap='RdYlGn', linewidths=0.2)
plt.show()

# %%
fig = plt.figure(figsize=(10,2))
sns.countplot(y='Survived', data=train)
print(train.Survived.value_counts())
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1, 2, figsize=(10, 6))

train['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived vs Dead')
ax[0].set_ylabel('')

sns.countplot('Survived',data=train, ax=ax[1])
ax[1].set_title('Survived vs Dead')

plt.show()

# %%
def piecount(col):
    f, ax = plt.subplots(1, 2, figsize=(10, 6))
    train[col].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], shadow=True)
    ax[0].set_title(col)
    ax[0].set_ylabel('')
    sns.countplot(col, data=train, ax=ax[1])
    ax[1].set_title(col)
    plt.show()

piecount('Survived')

# %% [markdown]
# (참고) 파이차트 간격두기
#
# train[col].value_counts().plot.pie(explode=[0.1 for i in range(train[col].nunique(), autopct='%1.1f%%', ax=ax[0], shadow=True)

# %%
train.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col1,#T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col0,#T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col1,#T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_18220066_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18220066_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_18220066_5996_11eb_a8cb_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_18220066_5996_11eb_a8cb_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_18220066_5996_11eb_a8cb_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_18220066_5996_11eb_a8cb_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 1등급 객실은 생존자가 많고, 3등급 객실은 사망자가 3배 이상 많다.

# %%
f, ax = plt.subplots(1, 2, figsize=(10, 6))
train[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived per Pcalss')
sns.countplot('Pclass', hue='Survived', data=train, ax=ax[1])
ax[1].set_title('Pclass Survived vs Dead')
plt.show()

# %%
piecount("Pclass")

# %%
data.Name.value_counts()
# Out:
# Kelly, Mr. James                          2
# Connolly, Miss. Kate                      2
# Abbott, Master. Eugene Joseph             1
# Masselmani, Mrs. Fatima                   1
# McCoy, Miss. Agnes                        1
#                                          ..
# Phillips, Mr. Escott Robert               1
# Head, Mr. Christopher                     1
# Chibnall, Mrs. (Edith Martha Bowerman)    1
# Payne, Mr. Vivian Ponsonby                1
# Sutton, Mr. Frederick                     1
# Name: Name, Length: 1307, dtype: int64

# %%
temp = data.copy()
temp['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Dr            8
# Rev           8
# Col           4
# Ms            2
# Mlle          2
# Major         2
# Dona          1
# Countess      1
# Don           1
# Lady          1
# Capt          1
# Jonkheer      1
# Sir           1
# Mme           1
# Name: Initial, dtype: int64

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Initial
# 0            1       0.0       3  ...   NaN        S       Mr
# 1            2       1.0       1  ...   C85        C      Mrs
# 2            3       1.0       3  ...   NaN        S     Miss
# 3            4       1.0       1  ...  C123        S      Mrs
# 4            5       0.0       3  ...   NaN        S       Mr
#
# [5 rows x 13 columns]

# %%
pd.crosstab(temp.Initial, temp.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col1,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col3,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col5,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col6,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col8,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col9,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col13,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col16,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col17,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col2,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col4,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col7,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col10,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col11,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col12,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col14,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col2,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col4,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col7,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col10,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col11,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col12,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col14,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col15,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col0,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col1,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col3,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col5,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col6,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col8,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col9,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col13,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col16,#T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col17{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dona</th>        <th class="col_heading level0 col5" >Dr</th>        <th class="col_heading level0 col6" >Jonkheer</th>        <th class="col_heading level0 col7" >Lady</th>        <th class="col_heading level0 col8" >Major</th>        <th class="col_heading level0 col9" >Master</th>        <th class="col_heading level0 col10" >Miss</th>        <th class="col_heading level0 col11" >Mlle</th>        <th class="col_heading level0 col12" >Mme</th>        <th class="col_heading level0 col13" >Mr</th>        <th class="col_heading level0 col14" >Mrs</th>        <th class="col_heading level0 col15" >Ms</th>        <th class="col_heading level0 col16" >Rev</th>        <th class="col_heading level0 col17" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col10" class="data row0 col10" >260</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col11" class="data row0 col11" >2</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col13" class="data row0 col13" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col14" class="data row0 col14" >197</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col15" class="data row0 col15" >2</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row0_col17" class="data row0 col17" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col5" class="data row1 col5" >7</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col9" class="data row1 col9" >61</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col13" class="data row1 col13" >757</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_18a486d0_5996_11eb_a8cb_0242ac1c0002row1_col16" class="data row1 col16" >8</td>

# %%
def survpct(col):
    return temp.groupby(col)['Survived'].mean()

survpct('Initial')
# Out:
# Initial
# Capt        0.000000
# Col         0.500000
# Countess    1.000000
# Don         0.000000
# Dona             NaN
# Dr          0.428571
# Jonkheer    0.000000
# Lady        1.000000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mlle        1.000000
# Mme         1.000000
# Mr          0.156673
# Mrs         0.792000
# Ms          1.000000
# Rev         0.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %%
temp.loc[temp['Initial'] == 'Dona']
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Initial
# 414         1306       NaN       1  ...  C105        C     Dona
#
# [1 rows x 13 columns]

# %%
temp.loc[temp['Initial'] == 'Dona', 'Initial'] = 'Mrs'

# %%
temp['LastName'] = data.Name.str.extract('([A-Za-z]+)')

# %%
pd.crosstab(temp.LastName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col3,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col4,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col5,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col8,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col9,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col10,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col12,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col13,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col16,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col17,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col18,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col22,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col23,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col24,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col27,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col29,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col33,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col34,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col35,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col37,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col39,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col42,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col43,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col44,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col48,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col53,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col54,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col55,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col56,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col59,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col63,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col66,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col67,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col68,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col69,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col71,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col73,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col74,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col75,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col77,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col78,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col81,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col82,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col83,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col85,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col86,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col89,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col91,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col92,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col93,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col94,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col95,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col97,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col99,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col101,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col102,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col103,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col105,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col106,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col110,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col112,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col115,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col116,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col118,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col119,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col120,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col121,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col124,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col126,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col127,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col128,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col129,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col131,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col132,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col133,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col135,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col137,#T_1972b6ae_5996_11eb_a8cb_0242ac1c0002row0_col139,#T_1972b6ae_5996_11eb_a8cb_0242a ...

# %%
temp['NumName'] = temp['LastName'].factorize()[0]

# %%
pd.crosstab(temp.NumName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col5,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col6,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col7,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col12,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col13,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col14,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col16,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col17,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col18,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col20,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col25,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col27,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col28,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col29,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col32,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col33,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col36,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col38,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col39,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col40,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col43,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col44,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col45,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col46,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col47,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col48,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col51,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col54,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col56,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col57,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col60,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col61,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col64,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col66,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col67,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col68,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col70,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col71,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col72,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col75,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col78,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col81,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col82,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col83,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col84,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col85,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col86,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col88,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col89,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col90,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col94,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col95,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col96,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col97,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col98,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col99,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col102,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col103,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col104,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col105,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col106,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col107,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col108,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col109,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col111,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col112,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col114,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col117,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col118,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col119,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col120,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col122,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col123,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col125,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col126,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col127,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col130,#T_1a398e8c_5996_11eb_a8cb_0242ac1c0002row0_col131,#T_1a398e8c_5996_11eb_a8cb_0242a ...

# %%
temp.loc[temp['LastName'] == 'Ali']
# Out:
#      PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 210          211       0.0       3  ...      Mr      Ali      182
# 784          785       0.0       3  ...      Mr      Ali      182
#
# [2 rows x 15 columns]

# %%
train[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# train.groupby(['Survived','Sex'])['Sex'].count() 와 비교하기

# %%
def twobar(col, target, title, title1):
    f,ax=plt.subplots(1,2,figsize=(10,5))
    train.groupby([col])[target].mean().plot(kind='bar', ax=ax[0])
    ax[0].set_title(title)
    sns.countplot(col, hue=target, data=train, ax=ax[1])
    ax[1].set_title(title1)
    plt.show()

twobar('Sex','Survived','Survived per Sex','Sex Survived vs Dead')

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# 남자의 수가 여자의 수보다 많지만, 생존율은 여성이 남성의 3배 이상이다.

# %%
pd.crosstab([train.Sex, train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col1,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col3,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col2,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col1,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col0,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col1,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col2,#T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1a986344_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_1a986344_5996_11eb_a8cb_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_1a986344_5996_11eb_a8cb_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
print('가장 나이가 많은 승객은', data['Age'].max(), '세 이다.')
print('가장 나이가 적은 승객은', data['Age'].min(), '세 이다.')
print('평균 나이는', int(data['Age'].mean()), '세 이다.')
# Out:
# 가장 나이가 많은 승객은 80.0 세 이다.
# 가장 나이가 적은 승객은 0.17 세 이다.
# 평균 나이는 29 세 이다.

# %%
sns.swarmplot(x=train['Survived'], y=train['Age'])
plt.xlabel("Survived")
plt.ylabel("Age")
plt.show()

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass", "Age", hue="Survived", data=train, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex","Age", hue="Survived", data=train, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# 1) 10세 미만의 어린이 수는 Pclass 3등급으로 갈수록 증가하고, 생존율은 Pclass에 상관없이 양호하다.
#
# 2) 20-40세는 Pclass 1등급에서 생존율이 높고, 여성이 더 높다.

# %%
#Initial별 평균Age 구하기
temp.groupby('Initial').agg({'Age': ['mean', 'count']})
# Out:
#                 Age
#                mean count
# Initial
# Capt      70.000000     1
# Col       54.000000     4
# Countess  33.000000     1
# Don       40.000000     1
# Dr        43.571429     7
# Jonkheer  38.000000     1
# Lady      48.000000     1
# Major     48.500000     2
# Master     5.482642    53
# Miss      21.774238   210
# Mlle      24.000000     2
# Mme       24.000000     1
# Mr        32.252151   581
# Mrs       37.005848   171
# Ms        28.000000     1
# Rev       41.250000     8
# Sir       49.000000     1

# %%
temp = temp.reset_index(drop=True)
temp['Age'] = temp.groupby('Initial')['Age'].apply(lambda x: x.fillna(x.mean()))
temp[55:60]
# Out:
#     PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 55           56       1.0       1  ...      Mr  Woolner       52
# 56           57       1.0       2  ...    Miss     Rugg       53
# 57           58       0.0       3  ...      Mr    Novel       54
# 58           59       1.0       2  ...    Miss     West       55
# 59           60       0.0       3  ...  Master  Goodwin       56
#
# [5 rows x 15 columns]

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         198
# Master       61
# Rev           8
# Dr            8
# Col           4
# Ms            2
# Mlle          2
# Major         2
# Countess      1
# Don           1
# Lady          1
# Capt          1
# Jonkheer      1
# Sir           1
# Mme           1
# Name: Initial, dtype: int64

# %%
temp.loc[temp['Initial'] == 'Jonkheer']
# Out:
#      PassengerId  Survived  Pclass  ...   Initial  LastName  NumName
# 822          823       0.0       1  ...  Jonkheer  Reuchlin      614
#
# [1 rows x 15 columns]

# %%
#Initial 매핑
temp['Initial'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dr', 'Jonkheer', 'Lady', 'Major', 'Master',  'Miss'  ,'Mlle', 'Mme', 'Mr', 'Mrs', 'Ms', 'Rev', 'Sir'], ['Sacrificed', 'Respected', 'Nobles', 'Mr', 'Respected', 'Mr', 'Nobles', 'Respected', 'Kids', 'Miss', 'Nobles', 'Nobles', 'Mr', 'Mrs', 'Nobles', 'Sacrificed', 'Nobles'], inplace=True)
temp['Initial'].replace(['Kids', 'Miss', 'Mr', 'Mrs', 'Nobles', 'Respected', 'Sacrificed'], [4, 4, 2, 5, 6, 3, 1], inplace=True)

# %%
temp['Age_Range'] = pd.qcut(temp['Age'], 10)

# %%
survpct('Age_Range')
# Out:
# Age_Range
# (0.169, 16.0]     0.548077
# (16.0, 21.0]      0.307692
# (21.0, 23.0]      0.487179
# (23.0, 26.0]      0.369863
# (26.0, 30.0]      0.400000
# (30.0, 32.252]    0.198718
# (32.252, 33.0]    0.411765
# (33.0, 39.0]      0.504762
# (39.0, 48.0]      0.357143
# (48.0, 80.0]      0.387500
# Name: Survived, dtype: float64

# %%
temp['Agroup'] = 0

temp.loc[temp['Age'] < 1.0, 'Agroup'] = 1
temp.loc[(temp['Age'] >=1.0) & (temp['Age'] <= 3.0), 'Agroup'] = 2
temp.loc[(temp['Age'] > 3.0) & (temp['Age'] < 11.0), 'Agroup'] = 7
temp.loc[(temp['Age'] >= 11.0) & (temp['Age'] < 15.0), 'Agroup'] = 13
temp.loc[(temp['Age'] >= 15.0) & (temp['Age'] < 18.0), 'Agroup'] = 16
temp.loc[(temp['Age'] >= 18.0) & (temp['Age'] <=  20.0), 'Agroup'] = 18
temp.loc[(temp['Age'] > 20.0) & (temp['Age'] <= 22.0), 'Agroup'] = 21
temp.loc[(temp['Age'] > 22.0) & (temp['Age'] <= 26.0), 'Agroup'] = 24
temp.loc[(temp['Age'] > 26.0) & (temp['Age'] <= 30.0), 'Agroup'] = 28
temp.loc[(temp['Age'] > 30.0) & (temp['Age'] <= 32.0), 'Agroup'] = 31
temp.loc[(temp['Age'] > 32.0) & (temp['Age'] <= 34.0), 'Agroup'] = 33
temp.loc[(temp['Age'] > 34.0) & (temp['Age'] <= 38.0), 'Agroup'] = 36
temp.loc[(temp['Age'] > 38.0) & (temp['Age'] <= 52.0), 'Agroup'] = 45
temp.loc[(temp['Age'] > 52.0) & (temp['Age'] <= 75.0), 'Agroup'] = 60
temp.loc[temp['Age'] > 75.0, 'Agroup'] = 78

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... NumName     Age_Range  Agroup
# 0            1       0.0       3  ...       0  (21.0, 23.0]      21
# 1            2       1.0       1  ...       1  (33.0, 39.0]      36
# 2            3       1.0       3  ...       2  (23.0, 26.0]      24
# 3            4       1.0       1  ...       3  (33.0, 39.0]      36
# 4            5       0.0       3  ...       4  (33.0, 39.0]      36
#
# [5 rows x 17 columns]

# %%
#Sex 매핑
temp.loc[(temp['Sex'] == 'male'), 'Sex'] = 1
temp.loc[(temp['Sex'] == 'female'), 'Sex'] = 2
temp.loc[(temp['Age'] < 1), 'Sex'] = 3

# %%
survpct('Sex')
# Out:
# Sex
# 1    0.181818
# 2    0.740385
# 3    1.000000
# Name: Survived, dtype: float64

# %%
temp.loc[(temp['SibSp'] == 0) & (temp['Parch'] == 0), 'Alone'] = 1
temp['Family'] = temp['SibSp'] + temp['Parch'] + 1
temp.head(n=10)
# Out:
#    PassengerId  Survived  Pclass  ... Agroup Alone  Family
# 0            1       0.0       3  ...     21   NaN       2
# 1            2       1.0       1  ...     36   NaN       2
# 2            3       1.0       3  ...     24   1.0       1
# 3            4       1.0       1  ...     36   NaN       2
# 4            5       0.0       3  ...     36   1.0       1
# 5            6       0.0       3  ...     33   1.0       1
# 6            7       0.0       1  ...     60   1.0       1
# 7            8       0.0       3  ...      2   NaN       5
# 8            9       1.0       3  ...     28   NaN       3
# 9           10       1.0       2  ...     13   NaN       2
#
# [10 rows x 19 columns]

# %%
survpct('Family')
# Out:
# Family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# (1) 혼자는 생존율이 낮다. 이는 혼자가 많은 젊은이들이 양보를 했다고 추측할 수 있다.
# (2) 가족이 4 명이상 있는 사람은 생존율이 낮다.

# %%
twobar('Parch', 'Survived', 'Survived per Parch', 'Parch Survived vs Dead')

# %% [markdown]
# 부모가 1~3명 있는 사람은 생존율이 높다.

# %%
pd.crosstab([temp.Family, temp.Survived], temp.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row3_col0{
#             background-color:  #c3e166;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col1{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col2{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col3{
#             background-color:  #95ca66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col0{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col2{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col3{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row2_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row2_col1{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row2_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row2_col3{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row3_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row3_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row5_col2{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row3_col3{
#             background-color:  #e7f366;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row4_col0{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row4_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row7_col1{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row4_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row4_col3{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row5_col0{
#             background-color:  #eaf466;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row5_col1{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row5_col3{
#             background-color:  #eff766;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row6_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row8_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row9_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row10_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row11_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row13_col2{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row6_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row10_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row12_col2{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row6_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row6_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row9_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row11_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row12_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row15_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row7_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row7_col3{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row7_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row14_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row15_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row8_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row8_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row9_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row9_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row10_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row11_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row11_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row12_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row12_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row13_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row13_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row13_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row14_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row14_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row14_col3,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row15_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row15_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row8_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row10_col2{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row16_col0,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row16_col1,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row16_col2,#T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row16_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Family</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>1</th>
#                         <th id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002level1_row0" class="row_heading level1 row0" >0.0</th>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col1" class="data row0 col1" >68</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col2" class="data row0 col2" >255</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row0_col3" class="data row0 col3" >374</td>
#             </tr>
#             <tr>
#                                 <th id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002level1_row1" class="row_heading level1 row1" >1.0</th>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >58</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col1" class="data row1 col1" >36</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col2" class="data row1 col2" >69</td>
#                         <td id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002row1_col3" class="data row1 col3" >163</td>
#             </tr>
#             <tr>
#                         <th id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>2</th>
#                         <th id="T_1bbc98b2_5996_11eb_a8cb_0242ac1c0002level1_row2" class="row_heading level1 row2" >0.0</th>
#                         <td id="T_1bbc98b2_

# %% [markdown]
# (1) Pclass 3등급으로 갈수록 식구가 많다.
# (2) 1~3명의 가족이 있는 귀족층은 생존율이 높다.

# %%
temp.Ticket.head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
temp.Ticket.isnull().any()
# Out:
# False

# %%
temp['Initick'] = temp.Ticket.str.extract('^([A-Za-z]+)')
temp = temp.reset_index(drop=True)
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Alone Family  Initick
# 0            1       0.0       3  ...   NaN      2        A
# 1            2       1.0       1  ...   NaN      2       PC
# 2            3       1.0       3  ...   1.0      1     STON
# 3            4       1.0       1  ...   NaN      2      NaN
# 4            5       0.0       3  ...   1.0      1      NaN
#
# [5 rows x 20 columns]

# %%
temp['NumTicket'] = temp['Initick'].factorize()[0]
temp.head(n=15)
# Out:
#     PassengerId  Survived  Pclass  ... Family Initick  NumTicket
# 0             1       0.0       3  ...      2       A          0
# 1             2       1.0       1  ...      2      PC          1
# 2             3       1.0       3  ...      1    STON          2
# 3             4       1.0       1  ...      2     NaN         -1
# 4             5       0.0       3  ...      1     NaN         -1
# 5             6       0.0       3  ...      1     NaN         -1
# 6             7       0.0       1  ...      1     NaN         -1
# 7             8       0.0       3  ...      5     NaN         -1
# 8             9       1.0       3  ...      3     NaN         -1
# 9            10       1.0       2  ...      2     NaN         -1
# 10           11       1.0       3  ...      3      PP          3
# 11           12       1.0       1  ...      1     NaN         -1
# 12           13       0.0       3  ...      1       A          0
# 13           14       0.0       3  ...      7     NaN         -1
# 14           15       0.0       3  ...      1     NaN         -1
#
# [15 rows x 21 columns]

# %%
survpct('NumTicket')
# Out:
# NumTicket
# -1     0.384266
#  0     0.068966
#  1     0.650000
#  2     0.444444
#  3     0.666667
#  4     0.454545
#  5     0.538462
#  6     0.142857
#  7     0.071429
#  8     1.000000
#  9     0.090909
#  10    0.117647
#  11    0.000000
#  12    0.250000
#  13    0.666667
#  14    1.000000
#  15    0.000000
#  16    0.500000
#  17    0.500000
#  18         NaN
#  19         NaN
# Name: Survived, dtype: float64

# %%
print('가장 높은 요금:', temp['Fare'].max())
print('가장 낮은 요금:', temp['Fare'].min())
print('평균요금:', temp['Fare'].mean())
# Out:
# 가장 높은 요금: 512.3292
# 가장 낮은 요금: 0.0
# 평균요금: 33.2954792813456

# %%
f,ax=plt.subplots(1, 3, figsize=(20, 6))
sns.distplot(train[train['Pclass'] == 1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(train[train['Pclass'] == 2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(train[train['Pclass'] == 3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %%
def groupmean(a,b):
    return temp.groupby([a])[b].mean().to_frame().style.background_gradient(cmap='summer_r')

temp['Fare_Range'] = pd.qcut(train['Fare'], 10)
groupmean('Fare_Range', 'Fare')
# Out:
# <style  type="text/css" >
# #T_1c480618_5996_11eb_a8cb_0242ac1c0002row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row1_col0,#T_1c480618_5996_11eb_a8cb_0242ac1c0002row2_col0{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row3_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row4_col0{
#             background-color:  #f3f966;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row5_col0{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row6_col0{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row7_col0{
#             background-color:  #d0e866;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row8_col0{
#             background-color:  #9ece66;
#             color:  #000000;
#         }#T_1c480618_5996_11eb_a8cb_0242ac1c0002row9_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1c480618_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fare</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" >(-0.001, 7.55]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >5.928717</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row1" class="row_heading level0 row1" >(7.55, 7.854]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >7.768490</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row2" class="row_heading level0 row2" >(7.854, 8.05]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row2_col0" class="data row2 col0" >7.963669</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row3" class="row_heading level0 row3" >(8.05, 10.5]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row3_col0" class="data row3 col0" >9.521367</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row4" class="row_heading level0 row4" >(10.5, 14.454]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row4_col0" class="data row4 col0" >12.940231</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row5" class="row_heading level0 row5" >(14.454, 21.679]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row5_col0" class="data row5 col0" >17.386408</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row6" class="row_heading level0 row6" >(21.679, 27.0]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row6_col0" class="data row6 col0" >25.487501</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row7" class="row_heading level0 row7" >(27.0, 39.688]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row7_col0" class="data row7 col0" >32.282186</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row8" class="row_heading level0 row8" >(39.688, 77.958]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row8_col0" class="data row8 col0" >59.444572</td>
#             </tr>
#             <tr>
#                         <th id="T_1c480618_5996_11eb_a8cb_0242ac1c0002level0_row9" class="row_heading level0 row9" >(77.958, 512.329]</th>
#                         <td id="T_1c480618_5996_11eb_a8cb_0242ac1c0002row9_col0" class="data row9 col0" >146.807086</td>
#             </tr>
#     </tbody></table>

# %%
temp['Fgroup'] = 0

temp.loc[temp['Fare'] <= 0,'Fgroup'] = 0
temp.loc[(temp['Fare'] > 0) & (temp['Fare'] <= 7.125), 'Fgroup'] = 1
temp.loc[(temp['Fare'] > 7.125) & (temp['Fare'] <= 7.9), 'Fgroup'] = 2
temp.loc[(temp['Fare'] > 7.9) & (temp['Fare'] <= 8.03), 'Fgroup'] = 3
temp.loc[(temp['Fare'] > 8.03) & (temp['Fare'] < 10.5), 'Fgroup'] = 4
temp.loc[(temp['Fare'] >= 10.5) & (temp['Fare'] < 23.0), 'Fgroup'] = 5
temp.loc[(temp['Fare'] >= 23.0) & (temp['Fare'] <= 27.8), 'Fgroup'] = 6
temp.loc[(temp['Fare'] > 27.8) & (temp['Fare'] <= 51.0), 'Fgroup'] = 7
temp.loc[(temp['Fare'] > 51.0) & (temp['Fare'] <= 73.5), 'Fgroup'] = 8
temp.loc[temp['Fare'] > 73.5, 'Fgroup'] = 9

temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... NumTicket        Fare_Range  Fgroup
# 0            1       0.0       3  ...         0    (-0.001, 7.55]       2
# 1            2       1.0       1  ...         1  (39.688, 77.958]       8
# 2            3       1.0       3  ...         2     (7.854, 8.05]       3
# 3            4       1.0       1  ...        -1  (39.688, 77.958]       8
# 4            5       0.0       3  ...        -1     (7.854, 8.05]       4
#
# [5 rows x 23 columns]

# %%
temp.Cabin.value_counts().head(10)
# Out:
# C23 C25 C27        6
# B57 B59 B63 B66    5
# G6                 5
# F2                 4
# F33                4
# C22 C26            4
# D                  4
# B96 B98            4
# C78                4
# F4                 4
# Name: Cabin, dtype: int64

# %%
temp.Cabin.value_counts().tail(10)
# Out:
# E40    1
# D40    1
# D48    1
# E10    1
# C28    1
# E52    1
# A6     1
# A29    1
# B36    1
# A9     1
# Name: Cabin, dtype: int64

# %%
temp.Cabin.isna().any()
# Out:
# True

# %%
temp.Cabin.isna().sum()
# Out:
# 1014

# %%
temp['Inicab'] = 0
temp['Inicab'] = temp['Cabin'].str.extract('^([A-Za-z]+)')
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 1)), 'Inicab'] = 'X'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 2)), 'Inicab'] = 'Y'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 3)), 'Inicab'] = 'Z'
    
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 0            1       0.0       3  ...    (-0.001, 7.55]      2       Z
# 1            2       1.0       1  ...  (39.688, 77.958]      8       C
# 2            3       1.0       3  ...     (7.854, 8.05]      3       Z
# 3            4       1.0       1  ...  (39.688, 77.958]      8       C
# 4            5       0.0       3  ...     (7.854, 8.05]      4       Z
#
# [5 rows x 24 columns]

# %%
temp['Inicab'] = temp['Inicab'].factorize()[0]
temp[11:20]
# Out:
#     PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 11           12       1.0       1  ...    (21.679, 27.0]      6       1
# 12           13       0.0       3  ...     (7.854, 8.05]      4       0
# 13           14       0.0       3  ...    (27.0, 39.688]      7       0
# 14           15       0.0       3  ...     (7.55, 7.854]      2       0
# 15           16       1.0       2  ...  (14.454, 21.679]      5       3
# 16           17       0.0       3  ...    (27.0, 39.688]      7       0
# 17           18       1.0       2  ...    (10.5, 14.454]      5       3
# 18           19       0.0       3  ...  (14.454, 21.679]      5       0
# 19           20       1.0       3  ...    (-0.001, 7.55]      2       0
#
# [9 rows x 24 columns]

# %%
pd.crosstab([temp.Embarked, temp.Pclass], [temp.Sex, temp.Survived], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col0,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col3{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col1{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col0{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col3,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col5{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col0,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col1,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col3,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row3_col5,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col0,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col1,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col5,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col5{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col1,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col5{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col3,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col0{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col1{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col3{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col4{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row2_col5,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col2{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row4_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col0{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col1{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col2{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row5_col5{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col0{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col3{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row6_col5{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col0{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col1{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row7_col3{
#             background-color:  #bcde66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col0{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col1{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col2{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col3{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row8_col5{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col0,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col1,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col2,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col3,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col4,#T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row9_col5{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>1</th>        <th class="col_heading level0 col2" colspan=2>2</th>        <th class="col_heading level0 col4" >3</th>        <th class="col_heading level0 col5" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0.0</th>        <th class="col_heading level1 col1" >1.0</th>        <th class="col_heading level1 col2" >0.0</th>        <th class="col_heading level1 col3" >1.0</th>        <th class="col_heading level1 col4" >1.0</th>        <th class="col_heading level1 col5" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col0" class="data row0 col0" >25</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col1" class="data row0 col1" >17</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col3" class="data row0 col3" >42</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row0_col5" class="data row0 col5" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002level1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_1c81b7d2_5996_11eb_a8cb_0242ac1c0002row1_col2" class="data row1 col2" >0</td>

# %%
sns.factorplot('Embarked', 'Survived', data=temp)
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(10,7))
sns.countplot('Embarked', data=temp, ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=temp, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=temp, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=temp, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.3,hspace=0.5)
plt.show()

# %% [markdown]
# (1) Embarked C의 생존율은 가장 높다.
# (2) Embarked S의 생존율은 가장 낮고, 탑승자가 제일 많다.

# %%
temp.loc[(temp.Embarked.isna())]
# Out:
#      PassengerId  Survived  Pclass  ...         Fare_Range Fgroup  Inicab
# 61            62       1.0       1  ...  (77.958, 512.329]      9       8
# 829          830       1.0       1  ...  (77.958, 512.329]      9       8
#
# [2 rows x 24 columns]

# %%
temp.loc[temp['Ticket'] == 113572]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initial, LastName, NumName, Age_Range, Agroup, Alone, Family, Initick, NumTicket, Fare_Range, Fgroup, Inicab]
# Index: []

# %%
temp.sort_values(['Ticket'], ascending = True)[50:70]
# Out:
#       PassengerId  Survived  Pclass  ...         Fare_Range Fgroup  Inicab
# 965           966       NaN       1  ...                NaN      9       1
# 377           378       0.0       1  ...  (77.958, 512.329]      9       1
# 166           167       1.0       1  ...   (39.688, 77.958]      8       2
# 356           357       1.0       1  ...   (39.688, 77.958]      8       2
# 917           918       NaN       1  ...                NaN      8       8
# 54             55       0.0       1  ...   (39.688, 77.958]      8       8
# 351           352       0.0       1  ...     (27.0, 39.688]      7       1
# 252           253       0.0       1  ...     (21.679, 27.0]      6       1
# 829           830       1.0       1  ...  (77.958, 512.329]      9       8
# 61             62       1.0       1  ...  (77.958, 512.329]      9       8
# 802           803       1.0       1  ...  (77.958, 512.329]      9       8
# 390           391       1.0       1  ...  (77.958, 512.329]      9       8
# 435           436       1.0       1  ...  (77.958, 512.329]      9       8
# 763           764       1.0       1  ...  (77.958, 512.329]      9       8
# 185           186       0.0       1  ...   (39.688, 77.958]      7       6
# 1073         1074       NaN       1  ...                NaN      8       5
# 748           749       0.0       1  ...   (39.688, 77.958]      8       5
# 151           152       1.0       1  ...   (39.688, 77.958]      8       1
# 336           337       0.0       1  ...   (39.688, 77.958]      8       1
# 932           933       NaN       1  ...                NaN      6       5
#
# [20 rows x 24 columns]

# %%
temp.loc[(temp.Embarked.isna()), 'Embarked'] = 'S'

# %%
temp['Embarked'] = temp['Embarked'].factorize()[0]
    
temp[11:20]
# Out:
#     PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 11           12       1.0       1  ...    (21.679, 27.0]      6       1
# 12           13       0.0       3  ...     (7.854, 8.05]      4       0
# 13           14       0.0       3  ...    (27.0, 39.688]      7       0
# 14           15       0.0       3  ...     (7.55, 7.854]      2       0
# 15           16       1.0       2  ...  (14.454, 21.679]      5       3
# 16           17       0.0       3  ...    (27.0, 39.688]      7       0
# 17           18       1.0       2  ...    (10.5, 14.454]      5       3
# 18           19       0.0       3  ...  (14.454, 21.679]      5       0
# 19           20       1.0       3  ...    (-0.001, 7.55]      2       0
#
# [9 rows x 24 columns]

# %%
survpct('Initial')
# Out:
# Initial
# 1    0.000000
# 2    0.156069
# 3    0.454545
# 4    0.675676
# 5    0.792000
# 6    1.000000
# Name: Survived, dtype: float64

# %%
survpct('Pclass')
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
survpct('Sex')
# Out:
# Sex
# 1    0.181818
# 2    0.740385
# 3    1.000000
# Name: Survived, dtype: float64

# %%
survpct('Age').head()
# Out:
# Age
# 0.17    NaN
# 0.33    NaN
# 0.42    1.0
# 0.67    1.0
# 0.75    1.0
# Name: Survived, dtype: float64

# %%
survpct('Fgroup')
# Out:
# Fgroup
# 0    0.066667
# 1    0.037037
# 2    0.232044
# 3    0.473684
# 4    0.144330
# 5    0.425000
# 6    0.489362
# 7    0.353535
# 8    0.564516
# 9    0.762887
# Name: Survived, dtype: float64

# %%
survpct('Family')
# Out:
# Family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# Priority 생성 및 매핑
#
# 1 : Nobles
# 2 : Women in Pclass 1
# 3 : Babies under 1
# 4 : Kids under 17 in Pclass 1
# 5 : Kids under 17 in Pclass 2
# 6 : Women in Pclass 2
# 7 : Higher Fare

# %%
temp['Priority'] = 0
temp.loc[(temp['Initial'] == 6), 'Priority'] = 1
temp.loc[(temp['Pclass'] == 1) & (temp['Sex'] == 2), 'Priority'] = 2
temp.loc[(temp['Age'] < 1), 'Priority'] = 3
temp.loc[(temp['Pclass'] == 1) & (temp['Age'] <= 17), 'Priority'] = 4
temp.loc[(temp['Pclass'] == 2) & (temp['Age'] <= 17), 'Priority'] = 5
temp.loc[(temp['Pclass'] == 2) & (temp['Sex'] == 2), 'Priority'] = 6
temp.loc[(temp['Fgroup'] == 9), 'Priority'] = 7

# %%
survpct('Priority')
# Out:
# Priority
# 0    0.229508
# 1    1.000000
# 2    0.965517
# 3    1.000000
# 4    1.000000
# 5    0.818182
# 6    0.921053
# 7    0.762887
# Name: Survived, dtype: float64

# %%
temp.Priority.value_counts()
# Out:
# 0    978
# 7    145
# 6    105
# 2     52
# 5     16
# 3      7
# 4      4
# 1      2
# Name: Priority, dtype: int64

# %%
#Female & High survived 생성 및 매핑
temp['FH'] = 0
temp.loc[(temp['Sex'] == 1), 'FH'] = 0
temp.loc[(temp['Sex'] == 2), 'FH'] = 1
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 2), 'FH'] = 2
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 3), 'FH'] = 3
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 4), 'FH'] = 4
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 1), 'FH'] = 5
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 2), 'FH'] = 6
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] == 3), 'FH'] = 7
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] >= 5), 'FH'] = 8

# %%
survpct('FH')
# Out:
# FH
# 0    0.191710
# 1    0.615385
# 2    0.333333
# 3    0.000000
# 7    0.666667
# 8    0.784553
# Name: Survived, dtype: float64

# %%
temp.FH.value_counts()
# Out:
# 0    847
# 8    354
# 1     89
# 7      8
# 2      7
# 3      4
# Name: FH, dtype: int64

# %%
temp['MH'] = 0
temp.loc[(temp['Sex'] == 2), 'MH'] = 0
temp.loc[(temp['Sex'] == 1), 'MH'] = 1
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 2), 'MH'] = 2
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 3), 'MH'] = 3
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 4), 'MH'] = 4
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 1), 'MH'] = 5
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 2), 'MH'] = 6
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] == 3), 'MH'] = 7
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] >= 5), 'MH'] = 8

# %%
survpct('MH')
# Out:
# MH
# 0    0.746082
# 1    0.094017
# 2    0.111111
# 3    0.000000
# 5    0.000000
# 6    0.000000
# 7    0.384615
# 8    0.253333
# Name: Survived, dtype: float64

# %%
temp.MH.value_counts()
# Out:
# 0    474
# 8    450
# 1    335
# 7     16
# 2     13
# 5      8
# 6      7
# 3      6
# Name: MH, dtype: int64

# %%
temp['FL'] = 0
temp.loc[(temp['Sex'] == 1), 'FL'] = 0
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] < 5), 'FL'] = 1
temp.loc[(temp['Sex'] == 2) & (temp['Fgroup'] != 3), 'FL'] = 2
temp.loc[(temp['Sex'] == 2) & (temp['FH'] == 1), 'FL'] = 3
temp.loc[(temp['Sex'] == 2) & (temp['Family'] < 2), 'FL'] = 4
temp.loc[(temp['Sex'] == 2) & (temp['Family'] > 4), 'FL'] = 5
temp.loc[(temp['Sex'] == 2) & (temp['Family'] == 1) & (temp['Pclass'] == 3), 'FL'] = 6

# %%
survpct('FL')
# Out:
# FL
# 0    0.191710
# 1    0.000000
# 2    0.809211
# 4    0.939394
# 5    0.272727
# 6    0.616667
# Name: Survived, dtype: float64

# %%
temp.FL.value_counts()
# Out:
# 0    847
# 2    225
# 6    100
# 4     94
# 5     41
# 1      2
# Name: FL, dtype: int64

# %%
temp['ML'] = 0
temp.loc[(temp['Sex'] == 2), 'ML'] = 0
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] < 5), 'ML'] = 1
temp.loc[(temp['Sex'] == 1) & (temp['Fgroup'] != 3), 'ML'] = 2
temp.loc[(temp['Sex'] == 1) & (temp['MH'] <7), 'ML'] = 3
temp.loc[(temp['Sex'] == 1) & (temp['Family'] < 2), 'ML'] = 4
temp.loc[(temp['Sex'] == 1) & (temp['Family'] > 4), 'ML'] = 5
temp.loc[(temp['Sex'] == 1) & (temp['Family'] == 1) & (temp['Pclass'] == 3), 'ML'] = 6

# %%
survpct('ML')
# Out:
# ML
# 0    0.746082
# 1    0.333333
# 2    0.318966
# 3    0.076923
# 4    0.217687
# 5    0.034483
# 6    0.121212
# Name: Survived, dtype: float64

# %%
temp.ML.value_counts()
# Out:
# 0    474
# 6    372
# 4    224
# 2    176
# 5     41
# 3     19
# 1      3
# Name: ML, dtype: int64

# %%
temp['F1'] = temp['Priority']
temp['F2'] = temp['FH']
temp['F3'] = temp['MH']
temp['F4'] = temp['FL']
temp['F5'] = temp['ML']
temp['F6'] = temp['Initial']
temp['F7'] = temp['Fgroup']
temp['F8'] = temp['NumName']
temp['F9'] = temp['NumTicket']
temp['F10'] = temp['Family']
temp['F11'] = temp['Embarked']
temp['F12'] = temp['Sex']
temp['F13'] = temp['Pclass']
