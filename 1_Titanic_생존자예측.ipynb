# %% [markdown]
# <a href="https://colab.research.google.com/github/mjkimcs/portfolio/blob/main/1_Titanic_%EC%83%9D%EC%A1%B4%EC%9E%90%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# 모델 튜닝 및 평가
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn import model_selection

# 경고 제거
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.environ['KAGGLE_USERNAME']='mjkimcs'
os.environ['KAGGLE_KEY']='3037e68094017402df6f5c07240879c2'

# %%
# !kaggle competitions download -c titanic
# !unzip '*.zip'
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# gender_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# unzip:  cannot find or open *.zip, *.zip.zip or *.zip.ZIP.
#
# No zipfiles found.

# %%
# !ls
# Out:
# gender_submission.csv  sample_data  test.csv  train.csv

# %% [markdown]
# (참고)로컬PC에서 csv파일 가져오기
#
# from google.colab import files
# uploaded = files.upload()
#
# import io
# train = pd.read_csv(io.BytesIO(uploaded['train.csv']))
# test = pd.read_csv(io.BytesIO(uploaded['test.csv']))

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare        Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000          204       889
# unique          NaN         NaN         NaN  ...         NaN          147         3
# top             NaN         NaN         NaN  ...         NaN  C23 C25 C27         S
# freq            NaN         NaN         NaN  ...         NaN            4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208          NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429          NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000          NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400          NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200          NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000          NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200          NaN       NaN
#
# [11 rows x 12 columns]

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.columns[0], train.columns[3:5]
# Out:
# ('PassengerId', Index(['Name', 'Sex'], dtype='object'))

# %%
train[5:20]
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# 14           15         0       3  ...   7.8542   NaN         S
# 15           16         1       2  ...  16.0000   NaN         S
# 16           17         0       3  ...  29.1250   NaN         Q
# 17           18         1       2  ...  13.0000   NaN         S
# 18           19         0       3  ...  18.0000   NaN         S
# 19           20         1       3  ...   7.2250   NaN         C
#
# [15 rows x 12 columns]

# %%
train.shape
# Out:
# (891, 12)

# %%
# train, test 행의 갯수
ntrain = train.shape[0]
ntest = test.shape[0]

# naming
y_train = train['Survived'].values
passId = test['PassengerId']

# train, test 병합
data = pd.concat((train, test))

# 병합한 data의 크기
print("data size is: {}".format(data.shape))
# Out:
# data size is: (1309, 12)

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# train.csv에서 342명이 살아남고, 549명이 사망했다.

# %%
missingno.matrix(data, figsize = (6,4))

# %%
data.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.isna().any()
# Out:
# PassengerId    False
# Survived        True
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.isna().any().any()
# Out:
# True

# %%
data.PassengerId.isna().any()
# Out:
# False

# %%
corr = data.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(14, 8))
plt.title('Overall Correlation of Titanic Features', fontsize=18)

sns.heatmap(corr, mask=mask, annot=False, cmap='RdYlGn', linewidths=0.2)
plt.show()

# %%
fig = plt.figure(figsize=(10,2))
sns.countplot(y='Survived', data=train)
print(train.Survived.value_counts())
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1, 2, figsize=(10, 6))

train['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived vs Dead')
ax[0].set_ylabel('')

sns.countplot('Survived',data=train, ax=ax[1])
ax[1].set_title('Survived vs Dead')

plt.show()

# %%
def piecount(col):
    f, ax = plt.subplots(1, 2, figsize=(10, 6))
    train[col].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], shadow=True)
    ax[0].set_title(col)
    ax[0].set_ylabel('')
    sns.countplot(col, data=train, ax=ax[1])
    ax[1].set_title(col)
    plt.show()

piecount('Survived')

# %% [markdown]
# (참고) 파이차트 간격두기
#
# train[col].value_counts().plot.pie(explode=[0.1 for i in range(train[col].nunique(), autopct='%1.1f%%', ax=ax[0], shadow=True)

# %%
train.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col0,#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col1,#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col0,#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col1,#T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_ea0150d6_58c0_11eb_926b_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 1등급 객실은 생존자가 많고, 3등급 객실은 사망자가 3배 이상 많다.

# %%
f, ax = plt.subplots(1, 2, figsize=(10, 6))
train[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived per Pcalss')
sns.countplot('Pclass', hue='Survived', data=train, ax=ax[1])
ax[1].set_title('Pclass Survived vs Dead')
plt.show()

# %%
piecount("Pclass")

# %%
data.Name.value_counts()
# Out:
# Kelly, Mr. James                                                     2
# Connolly, Miss. Kate                                                 2
# Somerton, Mr. Francis William                                        1
# Chapman, Mr. John Henry                                              1
# Fortune, Mrs. Mark (Mary McDougald)                                  1
#                                                                     ..
# West, Miss. Barbara J                                                1
# Attalah, Miss. Malake                                                1
# Duff Gordon, Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")    1
# Dorking, Mr. Edward Arthur                                           1
# Brown, Mrs. John Murray (Caroline Lane Lamson)                       1
# Name: Name, Length: 1307, dtype: int64

# %%
temp = data.copy()
temp['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Ms            2
# Major         2
# Mlle          2
# Mme           1
# Don           1
# Lady          1
# Countess      1
# Dona          1
# Capt          1
# Jonkheer      1
# Sir           1
# Name: Initial, dtype: int64

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Initial
# 0            1       0.0       3  ...   NaN        S       Mr
# 1            2       1.0       1  ...   C85        C      Mrs
# 2            3       1.0       3  ...   NaN        S     Miss
# 3            4       1.0       1  ...  C123        S      Mrs
# 4            5       0.0       3  ...   NaN        S       Mr
#
# [5 rows x 13 columns]

# %%
pd.crosstab(temp.Initial, temp.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col0,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col1,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col3,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col5,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col6,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col8,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col9,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col13,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col16,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col17,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col2,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col4,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col7,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col10,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col11,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col12,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col14,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col2,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col4,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col7,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col10,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col11,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col12,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col14,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col15,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col0,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col1,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col3,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col5,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col6,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col8,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col9,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col13,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col16,#T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col17{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ea92b332_58c0_11eb_926b_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dona</th>        <th class="col_heading level0 col5" >Dr</th>        <th class="col_heading level0 col6" >Jonkheer</th>        <th class="col_heading level0 col7" >Lady</th>        <th class="col_heading level0 col8" >Major</th>        <th class="col_heading level0 col9" >Master</th>        <th class="col_heading level0 col10" >Miss</th>        <th class="col_heading level0 col11" >Mlle</th>        <th class="col_heading level0 col12" >Mme</th>        <th class="col_heading level0 col13" >Mr</th>        <th class="col_heading level0 col14" >Mrs</th>        <th class="col_heading level0 col15" >Ms</th>        <th class="col_heading level0 col16" >Rev</th>        <th class="col_heading level0 col17" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea92b332_58c0_11eb_926b_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col10" class="data row0 col10" >260</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col11" class="data row0 col11" >2</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col13" class="data row0 col13" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col14" class="data row0 col14" >197</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col15" class="data row0 col15" >2</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row0_col17" class="data row0 col17" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_ea92b332_58c0_11eb_926b_0242ac1c0002level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col5" class="data row1 col5" >7</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col9" class="data row1 col9" >61</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col13" class="data row1 col13" >757</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_ea92b332_58c0_11eb_926b_0242ac1c0002row1_col16" class="data row1 col16" >8</td>

# %%
def survpct(col):
    return temp.groupby(col)['Survived'].mean()

survpct('Initial')
# Out:
# Initial
# Capt        0.000000
# Col         0.500000
# Countess    1.000000
# Don         0.000000
# Dona             NaN
# Dr          0.428571
# Jonkheer    0.000000
# Lady        1.000000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mlle        1.000000
# Mme         1.000000
# Mr          0.156673
# Mrs         0.792000
# Ms          1.000000
# Rev         0.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %%
temp.loc[temp['Initial'] == 'Dona']
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Initial
# 414         1306       NaN       1  ...  C105        C     Dona
#
# [1 rows x 13 columns]

# %%
temp.loc[temp['Initial'] == 'Dona', 'Initial'] = 'Mrs'

# %%
temp['LastName'] = data.Name.str.extract('([A-Za-z]+)')

# %%
pd.crosstab(temp.LastName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col0,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col3,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col4,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col5,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col8,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col9,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col10,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col12,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col13,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col16,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col17,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col18,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col22,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col23,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col24,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col27,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col29,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col33,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col34,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col35,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col37,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col39,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col42,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col43,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col44,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col48,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col53,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col54,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col55,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col56,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col59,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col63,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col66,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col67,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col68,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col69,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col71,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col73,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col74,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col75,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col77,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col78,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col81,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col82,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col83,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col85,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col86,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col89,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col91,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col92,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col93,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col94,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col95,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col97,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col99,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col101,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col102,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col103,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col105,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col106,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col110,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col112,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col115,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col116,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col118,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col119,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col120,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col121,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col124,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col126,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col127,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col128,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col129,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col131,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col132,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col133,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col135,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col137,#T_ece426a2_58c0_11eb_926b_0242ac1c0002row0_col139,#T_ece426a2_58c0_11eb_926b_0242a ...

# %%
temp['NumName'] = temp['LastName'].factorize()[0]

# %%
pd.crosstab(temp.NumName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col0,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col5,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col6,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col7,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col12,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col13,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col14,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col16,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col17,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col18,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col20,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col25,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col27,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col28,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col29,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col32,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col33,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col36,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col38,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col39,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col40,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col43,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col44,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col45,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col46,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col47,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col48,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col51,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col54,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col56,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col57,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col60,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col61,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col64,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col66,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col67,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col68,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col70,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col71,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col72,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col75,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col78,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col81,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col82,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col83,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col84,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col85,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col86,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col88,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col89,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col90,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col94,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col95,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col96,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col97,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col98,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col99,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col102,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col103,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col104,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col105,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col106,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col107,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col108,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col109,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col111,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col112,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col114,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col117,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col118,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col119,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col120,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col122,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col123,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col125,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col126,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col127,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col130,#T_eda428b2_58c0_11eb_926b_0242ac1c0002row0_col131,#T_eda428b2_58c0_11eb_926b_0242a ...

# %%
temp.loc[temp['LastName'] == 'Ali']
# Out:
#      PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 210          211       0.0       3  ...      Mr      Ali      182
# 784          785       0.0       3  ...      Mr      Ali      182
#
# [2 rows x 15 columns]

# %%
train[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# train.groupby(['Survived','Sex'])['Sex'].count() 와 비교하기

# %%
def twobar(col, target, title, title1):
    f,ax=plt.subplots(1,2,figsize=(10,5))
    train.groupby([col])[target].mean().plot(kind='bar', ax=ax[0])
    ax[0].set_title(title)
    sns.countplot(col, hue=target, data=train, ax=ax[1])
    ax[1].set_title(title1)
    plt.show()

twobar('Sex','Survived','Survived per Sex','Sex Survived vs Dead')

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# 남자의 수가 여자의 수보다 많지만, 생존율은 여성이 남성의 3배 이상이다.

# %%
pd.crosstab([train.Sex, train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col0,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col1,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col3,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col2,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col1,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col0,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col1,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col2,#T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_edf3cb74_58c0_11eb_926b_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
print('가장 나이가 많은 승객은', data['Age'].max(), '세 이다.')
print('가장 나이가 적은 승객은', data['Age'].min(), '세 이다.')
print('평균 나이는', int(data['Age'].mean()), '세 이다.')
# Out:
# 가장 나이가 많은 승객은 80.0 세 이다.
# 가장 나이가 적은 승객은 0.17 세 이다.
# 평균 나이는 29 세 이다.

# %%
sns.swarmplot(x=train['Survived'], y=train['Age'])
plt.xlabel("Survived")
plt.ylabel("Age")
plt.show()

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass", "Age", hue="Survived", data=train, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex","Age", hue="Survived", data=train, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# 1) 10세 미만의 어린이 수는 Pclass 3등급으로 갈수록 증가하고, 생존율은 Pclass에 상관없이 양호하다.
#
# 2) 20-40세는 Pclass 1등급에서 생존율이 높고, 여성이 더 높다.

# %%
#Initial별 평균Age 구하기
temp.groupby('Initial').agg({'Age': ['mean', 'count']})
# Out:
#                 Age
#                mean count
# Initial
# Capt      70.000000     1
# Col       54.000000     4
# Countess  33.000000     1
# Don       40.000000     1
# Dr        43.571429     7
# Jonkheer  38.000000     1
# Lady      48.000000     1
# Major     48.500000     2
# Master     5.482642    53
# Miss      21.774238   210
# Mlle      24.000000     2
# Mme       24.000000     1
# Mr        32.252151   581
# Mrs       37.005848   171
# Ms        28.000000     1
# Rev       41.250000     8
# Sir       49.000000     1

# %%
temp = temp.reset_index(drop=True)
temp['Age'] = temp.groupby('Initial')['Age'].apply(lambda x: x.fillna(x.mean()))
temp[55:60]
# Out:
#     PassengerId  Survived  Pclass  ... Initial LastName  NumName
# 55           56       1.0       1  ...      Mr  Woolner       52
# 56           57       1.0       2  ...    Miss     Rugg       53
# 57           58       0.0       3  ...      Mr    Novel       54
# 58           59       1.0       2  ...    Miss     West       55
# 59           60       0.0       3  ...  Master  Goodwin       56
#
# [5 rows x 15 columns]

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         198
# Master       61
# Rev           8
# Dr            8
# Col           4
# Major         2
# Ms            2
# Mlle          2
# Lady          1
# Mme           1
# Sir           1
# Don           1
# Countess      1
# Capt          1
# Jonkheer      1
# Name: Initial, dtype: int64

# %%
temp.loc[temp['Initial'] == 'Jonkheer']
# Out:
#      PassengerId  Survived  Pclass  ...   Initial  LastName  NumName
# 822          823       0.0       1  ...  Jonkheer  Reuchlin      614
#
# [1 rows x 15 columns]

# %%
#Initial 매핑
temp['Initial'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dr', 'Jonkheer', 'Lady', 'Major', 'Master',  'Miss'  ,'Mlle', 'Mme', 'Mr', 'Mrs', 'Ms', 'Rev', 'Sir'], ['Sacrificed', 'Respected', 'Nobles', 'Mr', 'Respected', 'Mr', 'Nobles', 'Respected', 'Kids', 'Miss', 'Nobles', 'Nobles', 'Mr', 'Mrs', 'Nobles', 'Sacrificed', 'Nobles'], inplace=True)
temp['Initial'].replace(['Kids', 'Miss', 'Mr', 'Mrs', 'Nobles', 'Respected', 'Sacrificed'], [4, 4, 2, 5, 6, 3, 1], inplace=True)

# %%
temp['Age_Range'] = pd.qcut(temp['Age'], 10)

# %%
survpct('Age_Range')
# Out:
# Age_Range
# (0.169, 16.0]     0.548077
# (16.0, 21.0]      0.307692
# (21.0, 23.0]      0.487179
# (23.0, 26.0]      0.369863
# (26.0, 30.0]      0.400000
# (30.0, 32.252]    0.198718
# (32.252, 33.0]    0.411765
# (33.0, 39.0]      0.504762
# (39.0, 48.0]      0.357143
# (48.0, 80.0]      0.387500
# Name: Survived, dtype: float64

# %%
temp['Agroup'] = 0

temp.loc[temp['Age'] < 1.0, 'Agroup'] = 1
temp.loc[(temp['Age'] >=1.0) & (temp['Age'] <= 3.0), 'Agroup'] = 2
temp.loc[(temp['Age'] > 3.0) & (temp['Age'] < 11.0), 'Agroup'] = 7
temp.loc[(temp['Age'] >= 11.0) & (temp['Age'] < 15.0), 'Agroup'] = 13
temp.loc[(temp['Age'] >= 15.0) & (temp['Age'] < 18.0), 'Agroup'] = 16
temp.loc[(temp['Age'] >= 18.0) & (temp['Age'] <=  20.0), 'Agroup'] = 18
temp.loc[(temp['Age'] > 20.0) & (temp['Age'] <= 22.0), 'Agroup'] = 21
temp.loc[(temp['Age'] > 22.0) & (temp['Age'] <= 26.0), 'Agroup'] = 24
temp.loc[(temp['Age'] > 26.0) & (temp['Age'] <= 30.0), 'Agroup'] = 28
temp.loc[(temp['Age'] > 30.0) & (temp['Age'] <= 32.0), 'Agroup'] = 31
temp.loc[(temp['Age'] > 32.0) & (temp['Age'] <= 34.0), 'Agroup'] = 33
temp.loc[(temp['Age'] > 34.0) & (temp['Age'] <= 38.0), 'Agroup'] = 36
temp.loc[(temp['Age'] > 38.0) & (temp['Age'] <= 52.0), 'Agroup'] = 45
temp.loc[(temp['Age'] > 52.0) & (temp['Age'] <= 75.0), 'Agroup'] = 60
temp.loc[temp['Age'] > 75.0, 'Agroup'] = 78

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... NumName     Age_Range  Agroup
# 0            1       0.0       3  ...       0  (21.0, 23.0]      21
# 1            2       1.0       1  ...       1  (33.0, 39.0]      36
# 2            3       1.0       3  ...       2  (23.0, 26.0]      24
# 3            4       1.0       1  ...       3  (33.0, 39.0]      36
# 4            5       0.0       3  ...       4  (33.0, 39.0]      36
#
# [5 rows x 17 columns]

# %%
#Sex 매핑
temp.loc[(temp['Sex'] == 'male'), 'Sex'] = 1
temp.loc[(temp['Sex'] == 'female'), 'Sex'] = 2
temp.loc[(temp['Age'] < 1), 'Sex'] = 3

# %%
survpct('Sex')
# Out:
# Sex
# 1    0.181818
# 2    0.740385
# 3    1.000000
# Name: Survived, dtype: float64
